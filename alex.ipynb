# %%
import pandas as pd
url = "https://raw.githubusercontent.com/GWC-DCMB/CapstoneProject/master/datasets/"
filepath = "tesla/Tesla_Deaths.csv"
df = pd.read_csv(url + filepath)
df.head(144)
# Out:
#      Year        Date   Country State  \
# 0    2021   1/22/2021       USA    AZ
# 1    2021   1/21/2021       USA    CO
# 2    2021   1/15/2021       USA    FL
# 3    2021   1/10/2021       USA    UT
# 4    2020  12/18/2020  Portugal   NaN
# ..    ...         ...       ...   ...
# 139  2014   7/14/2014       USA    CA
# 140  2014    7/4/2014       USA    CA
# 141  2014    7/4/2014       USA    CA
# 142  2013   11/2/2013       USA    CA
# 143  2013    4/2/2013       USA    CA
#
#                                            Description  Deaths  Tesla_driver  \
# 0            Tesla crashes into tree,occupants killed        2           1.0
# 1     Tesla hits car and car crashes,driver later d...       1           NaN
# 2     Head-on collision involving a Tesla,other dri...       1           NaN
# 3            Car collides with Tesla,both drivers die        2           1.0
# 4    Tesla driver crashes into pole and dies in res...       1           1.0
# ..                                                 ...     ...           ...
# 139                           Tesla kills motorcyclist       1           NaN
# 140                         Thief crashes stolen Tesla       1           1.0
# 141                        Tesla rear ends stopped car       3           NaN
# 142                                Tesla kills cyclist       1           NaN
# 143                     Tesla veers into opposite lane       2           NaN
#
#      Tesla_occupant  Other_vehicle  Cyclists_Peds  ...  Model  \
# 0               1.0            NaN            NaN  ...    NaN
# 1               NaN            1.0            NaN  ...    NaN
# 2               NaN            1.0            NaN  ...    NaN
# 3               NaN            1.0            NaN  ...    NaN
# 4               NaN            NaN            NaN  ...    NaN
# ..              ...            ...            ...  ...    ...
# 139             NaN            1.0            NaN  ...    NaN
# 140             NaN            NaN            NaN  ...    NaN
# 141             NaN            3.0            NaN  ...    NaN
# 142             NaN            NaN            1.0  ...    NaN
# 143             NaN            2.0            NaN  ...      S
#
#     AutoPilot_claimed  Verified_Tesla_Autopilot_Death  \
# 0                 NaN                             NaN
# 1                 NaN                             NaN
# 2                 NaN                             NaN
# 3                 NaN                             NaN
# 4                 NaN                             NaN
# ..                ...                             ...
# 139               NaN                             NaN
# 140               NaN                             NaN
# 141               NaN                             NaN
# 142               NaN                             NaN
# 143               NaN                             NaN
#
#                                                 Source  \
# 0    https://www.azcentral.com/story/news/local/pho...
# 1    https://www.kktv.com/2021/01/20/man-dies-from-...
# 2    https://www.actionnewsjax.com/news/local/st-jo...
# 3    https://www.deseret.com/utah/2021/1/10/2222429...
# 4    https://www.jn.pt/local/noticias/porto/felguei...
# ..                                                 ...
# 139  http://injurylawcentral.com/blog/dwight-dene-p...
# 140  https://www.theverge.com/2014/7/10/5888463/car...
# 141  https://insideevs.com/3-dead-in-toyota-corolla...
# 142  http://www.santacruzsentinel.com/general-news/...
# 143  http://articles.latimes.com/2013/apr/02/local/...
#
#                                 FARS_NHTSA_case_filing Note  \
# 0                                                  NaN  NaN
# 1                                                  NaN  NaN
# 2                                                  NaN  NaN
# 3                                                  NaN  NaN
# 4                                                  NaN  NaN
# ..                                                 ...  ...
# 139  https://www-fars.nhtsa.dot.gov/QueryTool/Query...  NaN
# 140  https://www-fars.nhtsa.dot.gov/QueryTool/Query...  NaN
# 141  https://www-fars.nhtsa.dot.gov/QueryTool/Query...  NaN
# 142                                     No FARS report  NaN
# 143  https://www-fars.nhtsa.dot.gov/QueryTool/Query...  NaN
#
#                   Deceased 1               Deceased 2 Deceased 3 Deceased 4
# 0                        NaN                      NaN        NaN         NaN
# 1                        NaN                      NaN        NaN         NaN
# 2                        NaN                      NaN        NaN         NaN
# 3                        NaN                      NaN        NaN         NaN
# 4                        NaN                      NaN        NaN         NaN
# ..                       ...                      ...        ...         ...
# 139                      NaN                      NaN        NaN         NaN
# 140              Joshua Slot                      NaN        NaN         NaN
# 141                      NaN                      NaN        NaN         NaN
# 142                      NaN                      NaN        NaN         NaN
# 143  Alberto Casique-Salinas  Armando Garcia-Gonzales        NaN         NaN
#
# [144 rows x 21 columns]
